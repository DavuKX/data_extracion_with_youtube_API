# %%
import pandas as pd
from googleapiclient.discovery import build
from IPython.display import JSON
import json
import parser
from dateutil import parser

# %%
api_key = 'AIzaSyD5aXORNj36m3KJX0Qf8J9ppECk4TLznjo'

# %%
channel_ids = ['UCYDVFfp_AN1WBiNwaf9522w', 
              #more channels
             ]

# %%
api_service_name = "youtube"
api_version = "v3"
    
# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    
    all_data = []

    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    #Loop trough items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
               'subscribers': item['statistics']['subscriberCount'],
               'views': item['statistics']['viewCount'],
               'totalViews': item['statistics']['videoCount'],
               'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
               }
        all_data.append(data)
    return(pd.DataFrame(all_data))

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#           channelName subscribers      views totalViews  \
# 0  Dr. Glaucomflecken      540000  171086357        147
#
#                  playlistId
# 0  UUYDVFfp_AN1WBiNwaf9522w

# %%
playlist_id = 'UUYDVFfp_AN1WBiNwaf9522w'
 
def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part="contentDetails",
                    playlistId= playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()
    
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])
        
        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 147

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute()

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description',
                                         'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favoriteCount',
                                           'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    return pd.DataFrame(all_video_info)

# %%
df = get_video_details(youtube, video_ids)
df
# Out:
#         video_id        channelTitle  \
# 0    f6FHEsjA1B4  Dr. Glaucomflecken
# 1    1LNf1vvuMVk  Dr. Glaucomflecken
# 2    a9eEzrVSe6Q  Dr. Glaucomflecken
# 3    faTQDF4xXhU  Dr. Glaucomflecken
# 4    BhAQjqr0ShE  Dr. Glaucomflecken
# ..           ...                 ...
# 142  XE-kRwu4WWo  Dr. Glaucomflecken
# 143  PP1Qc4FwlIU  Dr. Glaucomflecken
# 144  C5BD9DGXoYk  Dr. Glaucomflecken
# 145  mTWSFvuAY5o  Dr. Glaucomflecken
# 146  qoYG0gK3yBQ  Dr. Glaucomflecken
#
#                                                 title  \
# 0                     Is There a Doctor on the Plane?
# 1                 Prior Authorizations For Everybody!
# 2                             How Do I Find the Time?
# 3                          Everybody Wants a Jonathan
# 4                  The Annual Faculty Easter Egg Hunt
# ..                                                ...
# 142                                Men’s Health Month
# 143       Hello, it’s me, the real Dr. Glaucomflecken
# 144  How to Ace Your Neurosurgery Residency Interview
# 145                  Med student's First Day - part 2
# 146                  Med Student's First Day - Part 1
#
#                                            description                tags  \
# 0                                                                     None
# 1                       Aetna has fallen on hard times                None
# 2                                                                     None
# 3                                                                     None
# 4                        Everybody did such a good job                None
# ..                                                 ...                 ...
# 142  Check your balls! I have had testicular cancer...                None
# 143                                                                   None
# 144                                                                   None
# 145  Just so you know, the med student honored all ...                None
# 146  Knock knock, hi. This is part 1 of a med stude...  [medicine surgery]
#
#               publishedAt viewCount likeCount favoriteCount commentCount  \
# 0    2022-04-26T01:00:07Z    286117     24036             0          562
# 1    2022-04-25T14:15:45Z    167688     11415             0          898
# 2    2022-04-24T21:50:14Z    306241     25848             0          390
# 3    2022-04-23T19:49:44Z    221804     12270             0          656
# 4    2022-04-18T00:40:44Z    221906     13048             0          442
# ..                    ...       ...       ...           ...          ...
# 142  2021-11-17T03:07:18Z    165572      9491             0          233
# 143  2021-11-17T02:39:00Z    258874     13969             0          434
# 144  2021-11-16T16:20:02Z    778078     34628             0          622
# 145  2021-11-15T22:54:23Z    537684     16669             0          458
# 146  2021-03-12T06:54:41Z   1408409     36489             0         1032
#
#      duration definition caption
# 0       PT38S         hd   false
# 1     PT1M52S         hd   false
# 2       PT21S         hd   false
# 3     PT2M24S         hd   false
# 4      PT2M1S         hd   false
# ..        ...        ...     ...
# 142   PT1M18S         hd   false
# 143     PT57S         hd   false
# 144   PT1M12S         hd   false
# 145  PT12M40S         hd   false
# 146  PT14M55S         hd   false
#
# [147 rows x 13 columns]

# %% [markdown]
# # EDA

# %%
df.isnull().sum()
# Out:
# video_id           0
# channelTitle       0
# title              0
# description        0
# tags             146
# publishedAt        0
# viewCount          0
# likeCount          0
# favoriteCount      0
# commentCount       0
# duration           0
# definition         0
# caption            0
# dtype: int64

# %%
df.dtypes
# Out:
# video_id         object
# channelTitle     object
# title            object
# description      object
# tags             object
# publishedAt      object
# viewCount        object
# likeCount        object
# favoriteCount    object
# commentCount     object
# duration         object
# definition       object
# caption          object
# dtype: object

# %%
num_attribs = ['viewCount', 'likeCount', 'favoriteCount', 'commentCount']
df[num_attribs] = df[num_attribs].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
df['publishedAt'] = df['publishedAt'].apply(lambda x: parser.parse(x))
df['publishDayName'] = df['publishedAt'].apply(lambda x: x.strftime('%A'))

# %%
import isodate
df['durationsecs'] = df['duration'].apply(lambda x: isodate.parse_duration(x))
df['durationsecs'] = df['

# %%
df[['durationsecs', 'duration']]
# Out:
#        durationsecs  duration
# 0   0 days 00:00:38     PT38S
# 1   0 days 00:01:52   PT1M52S
# 2   0 days 00:00:21     PT21S
# 3   0 days 00:02:24   PT2M24S
# 4   0 days 00:02:01    PT2M1S
# ..              ...       ...
# 142 0 days 00:01:18   PT1M18S
# 143 0 days 00:00:57     PT57S
# 144 0 days 00:01:12   PT1M12S
# 145 0 days 00:12:40  PT12M40S
# 146 0 days 00:14:55  PT14M55S
#
# [147 rows x 2 columns]
